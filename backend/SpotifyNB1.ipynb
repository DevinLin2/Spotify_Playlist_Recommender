# %%
os.getcwd()
# Out:
# '/Users/liamjeske/Downloads'

# %%
import sqlalchemy as db
from sqlalchemy.orm import sessionmaker
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
import json
import numpy as np

import os


engine = db.create_engine('mysql+pymysql://root:password@localhost:3306/351_proj_db')
conn = engine.connect()
inspect = db.inspect(engine)

inspect.get_table_names()
# Out:
# ['master', 'playlist', 'playlist_stats', 'playlist_track', 'track']

# %%
import os
os.getcwd()
# Out:
# '/Users/liamjeske/Downloads'

# %%
s = r"/Users/liamjeske/Downloads/spotify_million_playlist_dataset/data"

# assign directory
directory = s

jsons = []
# iterate over files in
# that directory
for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    # checking if it is a file
    if os.path.isfile(f):
        jsons.append(f)

# %%
jsons
# Out:
# ['/Users/liamjeske/Downloads/spotify_million_playlist_dataset/data/mpd.slice.549000-549999.json',
#  '/Users/liamjeske/Downloads/spotify_million_playlist_dataset/data/mpd.slice.613000-613999.json',
#  '/Users/liamjeske/Downloads/spotify_million_playlist_dataset/data/mpd.slice.115000-115999.json',
#  '/Users/liamjeske/Downloads/spotify_million_playlist_dataset/data/mpd.slice.778000-778999.json',
#  '/Users/liamjeske/Downloads/spotify_million_playlist_dataset/data/mpd.slice.290000-290999.json',
#  '/Users/liamjeske/Downloads/spotify_million_playlist_dataset/data/mpd.slice.596000-596999.json',
#  '/Users/liamjeske/Downloads/spotify_million_playlist_dataset/data/mpd.slice.324000-324999.json',
#  '/Users/liamjeske/Downloads/spotify_million_playlist_dataset/data/mpd.slice.422000-422999.json',
#  '/Users/liamjeske/Downloads/spotify_million_playlist_dataset/data/mpd.slice.974000-974999.json',
#  '/Users/liamjeske/Downloads/spotify_million_playlist_dataset/data/mpd.slice.679000-679999.json',
# ...

# %% [markdown]
# # Load the first json slice

# %%
pd.read_sql("SELECT DISTINCT artist_name from MASTER", conn).to_csv("/Users/liamjeske/Downloads/artists_unique.csv")

# %%
pd.read_sql("SELECT DISTINCT top_genre_1 from MASTER", conn).to_csv("/Users/liamjeske/Downloads/genres1_unique.csv")

# %%
data = json.load(open(jsons[0]))

# %% [markdown]
# # Examine the first playlist

# %%
data['playlists'][0]
# Out:
# {'name': 'Bob Dylan',
#  'collaborative': 'false',
#  'pid': 549000,
#  'modified_at': 1454803200,
#  'num_tracks': 75,
#  'num_albums': 65,
#  'num_followers': 1,
#  'tracks': [{'pos': 0,
#    'artist_name': 'Bob Dylan',
#    'track_uri': 'spotify:track:6QHYEZlm9wyfXfEM1vSu1P',
#    'artist_uri': 'spotify:artist:74ASZWbe4lXaubB36ztrGX',
#    'track_name': 'Boots of Spanish Leather',
#    'album_uri': 'spotify:album:7DZeLXvr9eTVpyI1OlqtcS',
#    'duration_ms': 277106,
#    'album_name': "The Times They Are A-Changin'"},
#   {'pos': 1,
#    'artist_name': 'Bob Dylan',
#    'track_uri': 'spotify:track:3RkQ3UwOyPqpIiIvGVewuU',
#    'artist_uri': 'spotify:artist:74ASZWbe4lXaubB36ztrGX',
#    'track_name': 'Mr. Tambourine Man',
#    'album_uri': 'spotify:album:1lPoRKSgZHQAYXxzBsOQ7v',
#    'duration_ms': 330533,
#    'album_name': 'Bringing It All Back Home'},
#   {'pos': 2,
#    'artist_name': 'Loggins & Messina',
#    'track_uri': 'spotify:track:0ju1jP0cSPJ8tmojYBEI89',
# ...

# %% [markdown]
# # Look at the tracks of the first playlist

# %%
df = pd.DataFrame(data['playlists'])

# %% [markdown]
# # Names of playlists that share the same name at least 3 times

# %%
temp = df['name'].value_counts()
temp[temp>2]
# Out:
# Party           5
# Summer          5
# EDM             5
# jams            4
# Worship         4
# running         3
# christmas       3
# happy           3
# Dance           3
# 2013            3
# ❤️              3
# 90s             3
# Rock            3
# new             3
# Christmas       3
# summer          3
# 2000s           3
# Throwback       3
# throwbacks      3
# 80s             3
# playlist        3
# Running         3
# chill out       3
# Classic Rock    3
# Calm            3
# August          3
# Spring 2016     3
# sleep           3
# party           3
# Name: name, dtype: int64

# %% [markdown]
# # Not all playlists have descriptions
#
# There is some nested structure in the tracks section that will have to be dealt with

# %%
df = pd.DataFrame(data['playlists'])
df = df.set_index('pid')
df[~df['description'].isna() ].head(20)
# Out:
#                       name collaborative  modified_at  num_tracks  num_albums  \
# pid
# 549056         Indie Vibes         false   1508630400         154         108
# 549063                Warm         false   1506816000          31           9
# 549103          GIrl power         false   1508544000          27          22
# 549169          morning ;)         false   1507766400          19          19
# 549196          spring '17         false   1494720000         100          62
# 549202              Summer         false   1508716800          32          29
# 549313             makeout         false   1489881600          41          26
# 549319              yeehaw         false   1505692800          76          51
# 549450          just chill         false   1493510400          22          22
# 549473           christmas         false   1482364800          40          36
# 549550                Edgy         false   1497052800          97           9
# ...

# %% [markdown]
# # TODO : Normalize json

# %%
df.isna().sum()
# Out:
# name               0
# collaborative      0
# modified_at        0
# num_tracks         0
# num_albums         0
# num_followers      0
# tracks             0
# num_edits          0
# duration_ms        0
# num_artists        0
# description      980
# dtype: int64

# %%
df.head().iloc[1]['tracks']
# Out:
# [{'pos': 0,
#   'artist_name': 'JAY Z',
#   'track_uri': 'spotify:track:2IUylG1WDsYWbMwH3HKuQo',
#   'artist_uri': 'spotify:artist:3nFkdlSjzX9mRTtwJOzDYB',
#   'track_name': "Big Pimpin' - Radio Edit",
#   'album_uri': 'spotify:album:2ZZiI4Jg5SYg7suQwGSv4z',
#   'duration_ms': 283933,
#   'album_name': 'R&B Classics Collection'},
#  {'pos': 1,
#   'artist_name': 'JAY Z',
#   'track_uri': 'spotify:track:3lPAHV0b53zgRRm9LBgnTY',
#   'artist_uri': 'spotify:artist:3nFkdlSjzX9mRTtwJOzDYB',
#   'track_name': 'Empire State Of Mind',
#   'album_uri': 'spotify:album:22v70dJq6kWS32SkR2c7kd',
#   'duration_ms': 276920,
#   'album_name': 'The Blueprint 3'},
#  {'pos': 2,
#   'artist_name': 'Beyoncé',
#   'track_uri': 'spotify:track:6jG2YzhxptolDzLHTGLt7S',
#   'artist_uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m',
#   'track_name': 'Drunk in Love',
#   'album_uri': 'spotify:album:2UJwKSBUz6rtW4QLK74kQu',
#   'duration_ms': 323480,
#   'album_name': 'BEYONCÉ [Platinum Edition]'},
#  {'pos': 3,
# ...

# %%
df.drop(columns=['tracks']).to_sql(con=conn,name="Platlists",if_exists='replace')
# Out:
# 1000

# %%
df.sample(10)
# Out:
#                    name collaborative  modified_at  num_tracks  num_albums  \
# pid
# 549414             Calm         false   1508630400          45          31
# 549997          WORSHIP         false   1488672000          51          45
# 549892     Take It Easy         false   1447200000          29          24
# 549857     chill vibes          false   1457395200          15           9
# 549589      california          false   1507680000         135          90
# 549527           random         false   1484784000          30          30
# 549265  Rock en Español         false   1459987200          27          19
# 549515          littttt         false   1500854400          76          54
# 549854             YEET         false   1493164800          18          18
# 549262        Roadtrip          false   1491696000         181         154
#
#         num_followers                                             tracks  \
# pid
# ...

# %%
j_norm = pd.json_normalize(data['playlists'], 
                    sep="_",
                    record_path=["tracks"])


j_norm.head(10)
# Out:
#    pos        artist_name                             track_uri  \
# 0    0          Bob Dylan  spotify:track:6QHYEZlm9wyfXfEM1vSu1P
# 1    1          Bob Dylan  spotify:track:3RkQ3UwOyPqpIiIvGVewuU
# 2    2  Loggins & Messina  spotify:track:0ju1jP0cSPJ8tmojYBEI89
# 3    3          Bob Dylan  spotify:track:7ny2ATvjtKszCpLpfsGnVQ
# 4    4          Bob Dylan  spotify:track:18GiV1BaXzPVYpp9rmOg0E
# 5    5          Bob Dylan  spotify:track:0wfBooQ6QtDm63UIyIcDIj
# 6    6          Bob Dylan  spotify:track:3xNO6JUk9ySYjxuqzcZYRB
# 7    7          Bob Dylan  spotify:track:5ka7NFOlZUpVLJmA2tO0o4
# 8    8          Bob Dylan  spotify:track:2FDTgrYDUdQKyGmtynEk90
# 9    9      The Lumineers  spotify:track:2GbmNHjKB1HxSnyobburxg
#
#                               artist_uri                  track_name  \
# 0  spotify:artist:74ASZWbe4lXaubB36ztrGX    Boots of Spanish Leather
# 1  spotify:artist:74ASZWbe4lXaubB36ztrGX          Mr. Tambourine Man
# ...

# %%
def split_strip(s, d=':', pos=2):
    return(str(s).split(d)[pos])

j_norm['artist_uri'] = j_norm['artist_uri'].apply(split_strip)
j_norm['track_uri'] = j_norm['track_uri'].apply(split_strip)
j_norm['album_uri'] = j_norm['album_uri'].apply(split_strip)



j_norm
# Out:
#        pos                  artist_name               track_uri  \
# 0        0                    Bob Dylan  6QHYEZlm9wyfXfEM1vSu1P
# 1        1                    Bob Dylan  3RkQ3UwOyPqpIiIvGVewuU
# 2        2            Loggins & Messina  0ju1jP0cSPJ8tmojYBEI89
# 3        3                    Bob Dylan  7ny2ATvjtKszCpLpfsGnVQ
# 4        4                    Bob Dylan  18GiV1BaXzPVYpp9rmOg0E
# ...    ...                          ...                     ...
# 68684   19              Robert Schumann  6cA1vWAvwPKOqDwbL75wS3
# 68685   20           Claudio Monteverdi  0Qe5L7l40nxZSSANHZgauB
# 68686   21  Giovanni Battista Pergolesi  5vlhQNiopUp6forIGnFi02
# 68687   22                Henry Purcell  2kmJLaxxFGk3cinoc1bvMb
# 68688   23                Henry Purcell  6lcMAqoEDqGh1nTBvsar0g
#
#                    artist_uri  \
# 0      74ASZWbe4lXaubB36ztrGX
# 1      74ASZWbe4lXaubB36ztrGX
# 2      7emRV8AluG3d4e5T0DZiK9
# 3      74ASZWbe4lXaubB36ztrGX
# 4      74ASZWbe4lXaubB36ztrGX
# ...

# %%
df.columns
# Out:
# Index(['name', 'collaborative', 'modified_at', 'num_tracks', 'num_albums',
#        'num_followers', 'tracks', 'num_edits', 'duration_ms', 'num_artists',
#        'description'],
#       dtype='object')

# %% [markdown]
# # Requests from Spotify API

# %%
import requests

client_ID = '43a5bf312135477c85e48e6731f65324'
client_secret = '1b0d671312ae4afaa462ef668e0cfbfb'
url = 'https://api.spotify.com/v1/audio-features'

#track_refs = [i.split(':')[2] for i in j_norm.head(10)['track_uri'].values]
#print(f"track_refs = {track_refs}")

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=client_ID, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)
response = sp.audio_features(j_norm['track_uri'].values[:100])

# %%
temp_df = pd.DataFrame(response)
temp_df['song_name'] = j_norm['track_name'][:100]
temp_df['artist_name'] = j_norm['artist_name']
temp_df = temp_df.set_index(['song_name', 'artist_name']).sort_values(by=['artist_name','song_name' ]).iloc[:,:11]
temp_df
# Out:
#                                                                   danceability  \
# song_name                                          artist_name
# It Makes Me Ill                                    *NSYNC                0.813
# I Don't Want to Miss a Thing - From the Touchst... Aerosmith             0.390
# Love Me Harder                                     Ariana Grande         0.476
# How Deep Is Your Love                              Bee Gees              0.633
# Drunk in Love                                      Beyoncé               0.583
# ...                                                                        ...
# Drops of Jupiter                                   Train                 0.481
# Meet Virginia                                      Train                 0.675
# Parachute                                          Train                 0.449
# This Ain't Goodbye                                 Train                 0.432
# ...

# %% [markdown]
# ## Last FM

# %% [markdown]
# - Application name	CSDS351 Enhanced Playlist Search
# - API key	a0a92e62924fb5da48d61306e0099ca4
# - Shared secret	33ca79170b3fce7af8cd9a074bb09b46
# - Registered to	lcj15

# %%
last_key = "a0a92e62924fb5da48d61306e0099ca4"
artist = 'Taylor Swift'
track_name = '22'
last_url = "http://ws.audioscrobbler.com/2.0/?method=track.gettoptags&artist={artist}&track={track_name}&api_key={last_key}&autocorrect=1&format=json"
r = requests.get(last_url)

# %%
t1 = (10001, 43, 1)
t2 = (10002, 43, 1)
t3 = (10003, 43, 1)
ts = (t1, t2, t3)

d = dict()

for i in ts:
    d[i[0]] = (i[1], i[2])

d.values()
# Out:
# dict_values([(43, 1), (43, 1), (43, 1)])

# %%
artists = ['Michael Jackson', 'Death Grips']
genres = ['sad', 'country']
acousticness = 0
danceability = 0
energy = -1
instrumentalness = 0
liveliness = 0
loudness = 0
speechiness = 0
tempo = -1
valence = -1

d = dict()
d['artists'] = artists
d['genres'] = genres
d['acousticness'] = acousticness
d['danceability'] = danceability
d['energy'] = energy
d['instrumentalness'] = instrumentalness
d['liveliness'] = liveliness

d
# Out:
# {'artists': ['Michael Jackson', 'Death Grips'],
#  'genres': ['sad', 'country'],
#  'acousticness': 0,
#  'danceability': 0,
#  'energy': -1,
#  'instrumentalness': 0,
#  'liveliness': 0}
